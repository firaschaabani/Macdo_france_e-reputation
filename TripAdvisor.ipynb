# %%
import numpy as np
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
## from pywaffle import Waffle
from wordcloud import WordCloud
##import goslate
import urllib
import urllib.request as urllib2
from collections import Counter
 ##import spacy

import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-ce83c274e4bb> in <module>
#       2 import requests
#       3 import pandas as pd
# ----> 4 from bs4 import BeautifulSoup
#       5 import numpy as np
#       6 ## from pywaffle import Waffle
#
# ModuleNotFoundError: No module named 'bs4'

# %%
nlp = spacy.load("fr_core_news_sm")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8f4c0b2c70cd> in <module>
# ----> 1 nlp = spacy.load("fr_core_news_sm")
#
# NameError: name 'spacy' is not defined

# %% [markdown]
# # 1. Import data

# %%
job_elems=""

df=pd.DataFrame()
titre=[]
avis=[]
date_visite=[]
date_pub=[]
nom=[]
URL=[]
stars=[]
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html')

URL.append('https://www.tripadvisor.fr/Restaurant_Review-g1067709-d12597814-Reviews-or-Mc_Donald_s-Cucq_Pas_de_Calais_Hauts_de_France.html')
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g666402-d8297375-Reviews-or-McDonald_s-Berck_Pas_de_Calais_Hauts_de_France.html')      
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g1580268-d7351137-Reviews-or-Mc_donald_s-Gardanne_Bouches_du_Rhone_Provence_Alpes_Cote_d_Azur.html')   
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g661455-d7226102-Reviews-or-Mc_Donald_s_Bonneuil_Sur_Marne-Bonneuil_sur_Marne_Val_de_Marne_Ile_de_France.html')    
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g196518-d8297418-Reviews-or-McDonald_s-City_of_Issoire_Issoire_Puy_de_Dome_Auvergne_Rhone_Alpes.html')   
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g196550-d7231255-Reviews-or-McDonald_s-Vierzon_Cher_Berry_Centre_Val_de_Loire.html')   
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g2501981-d3248993-Reviews-or-McDonald_s-Dorlisheim_Bas_Rhin_Grand_Est.html')
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g187234-d5965239-Reviews-or-Mc_Donald_s-Nice_French_Riviera_Cote_d_Azur_Provence_Alpes_Cote_d_Azur.html') 
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g675067-d4452395-Reviews-or-Mc_Donald_s-Quetigny_Cote_d_Or_Bourgogne_Franche_Comte.html')    
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g681196-d1334753-Reviews-or-Mc_Donald_s-Aubenas_Ardeche_Auvergne_Rhone_Alpes.html')   
URL.append('https://www.tripadvisor.fr/Restaurant_Review-g635821-d1333599-Reviews-or-Restaurant_Mc_Donald_s_Drive-Saint_Herblain_Nantes_Loire_Atlantique_Pays_de_la_Lo.html')

# %%
a,b = URL[0].split('-or')
print(a)
print(b)

a,b = URL[1].split('-or')
print(a)
print(b)

a,b = URL[2].split('-or')
print(a)
print(b)
# Out:
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews
# -McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1067709-d12597814-Reviews
# -Mc_Donald_s-Cucq_Pas_de_Calais_Hauts_de_France.html
# https://www.tripadvisor.fr/Restaurant_Review-g666402-d8297375-Reviews
# -McDonald_s-Berck_Pas_de_Calais_Hauts_de_France.html

# %%
for k in URL:
    for i in range(0,50,10):
        j=str(i)
        
        a,b = k.split('-or')
        Url=a+'-or'+j+b
   
     
    
    #RL = 'https://www.tripadvisor.fr/Restaurant_Review-g1067709-d12597814-Reviews-or'+j+'-Mc_Donald_s-Cucq_Pas_de_Calais_Hauts_de_France.html'
        print(Url)
        page = requests.get(Url)
        soup = BeautifulSoup(page.content, 'html.parser')
        for sub_heading in soup.find_all('span',class_='noQuotes'):
            rslt=sub_heading.text
            rslt=str(rslt)
        #df.loc[0, 'Titre'] =rslt
            titre.append(rslt)
        for sub_heading in soup.find_all("div", class_= "ui_column is-9"):
            mydivs = sub_heading
            for div in mydivs:
                
                z=str(div["class"])
                z=z[len(z)-4]    
                stars=stars+list(z)
        
                break 
                
        for sub_heading in soup.find_all('div',class_='info_text pointer_cursor'):
            rslt=sub_heading.text
            rslt=str(rslt)
        #df.loc[0, 'Titre'] =rslt
            nom.append(rslt)  
        
        for sub_heading in soup.find_all('span',class_='ratingDate'):
        
            rslt=sub_heading.text
            rslt=str(rslt)
            rslt=rslt[14:-1]
        #df.loc[0, 'Titre'] =rslt
            date_pub.append(rslt)    
        for sub_heading in soup.find_all(class_='prw_rup prw_reviews_stay_date_hsx'):
        
            rslt=sub_heading.text
            rslt=str(rslt)
            rslt=rslt[19:50]
        #df.loc[0, 'Titre'] =rslt
            date_visite.append(rslt)  
        
        for sub_heading in soup.find_all('p',class_='partial_entry'):
        
        
            rslt=sub_heading.text
            rslt=str(rslt)
            avis.append(rslt)
# Out:
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or0-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or10-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or20-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or30-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1180970-d7716775-Reviews-or40-McDonald_s-Serres_Castet_Bearn_Bearn_Basque_Country_Pyrenees_Atlantiques_N.html
# https://www.tripadvisor.fr/Restaurant_Review-g1067709-d12597814-Reviews-or0-Mc_Donald_s-Cucq_Pas_de_Calais_Hauts_de_France.html
# ...

# %%
len(avis)
# Out:
# 579

# %%
df=pd.DataFrame()

df['Titre']=titre
df['Avis']=avis[0:len(avis)-1]
df['Nom']=nom
df['Date_pub']=date_pub
df['Date_visite']=date_visite
df['Stars']=stars





df.head(5)
# Out:
#                                                Titre  \
# 0         Impossible de valider les points fidélités
# 1  Restaurant TRÈS TRÈS SALE,  service pitoyable ...
# 2                                               Long
# 3                                             Dépité
# 4                            Toujours des oublies!!!
#
#                                                 Avis                  Nom  \
# 0  Organisation nulle. Impossible de valider les ...             Kinaki64
# 1  Je savais que ce Mcdo était lent et qu'ils ess...           Juju_64000
# 2  Pour 3 café  plus viennoisrie 30 min de attent...             benoit l
# 3  J'habite à 10min de ce resto, pratique pour y ...  Destribois-Frederic
# 4  Encore et toujours!!!\nSi ce n'est pas une sau...  Destribois-Frederic
#
#            Date_pub     Date_visite Stars
# 0    5 janvier 2020    janvier 2020     1
# 1  17 décembre 2019   décembre 2019     1
# 2   1 novembre 2019   novembre 2019     1
# ...

# %%
for i in range(0,440 ,1):
    
    s=0
    if "2018" in df.iloc[i]['Date_visite']:
        s+=1;
    elif "2019" in df.iloc[i]['Date_visite']:
        s+=1
    elif "2020"in df.iloc[i]['Date_visite']:
        s+=1
    else :
        df = df.drop(i)

# %%
df.shape
# Out:
# (440, 6)

# %%
df.to_csv ('tripadvasor.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-980ef3271afc> in <module>
# ----> 1 df.to_csv ('tripadvasor.csv')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # 2. Tokenisation

# %% [markdown]
# ## Par mot

# %%
def return_token(sentence):
    # Tokeniser la phrase
   
     # remove stop words
    doc = [word.strip(string.punctuation) for word in sentence.split(" ")]
      # remove empty tokens
    doc = [t for t in doc if len(t) > 0]
     # remove words with only one letter
    doc = [t for t in doc if len(t) > 1]
      # remove words that contain numbers
    doc = [word for word in doc if not any(c.isdigit() for c in word)]
     # pos tag text
    pos_tags = pos_tag(doc)
    # lemmatize text
    doc = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    
    
    
    # Retourner le texte de chaque token
    return doc

# %%
from nltk.corpus import wordnet

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
All_text = ' '.join(text for text in df['Avis'])
# lower text
All_text = All_text.lower()
df["review_clean"] = df["Avis"].apply(lambda x: " ".join(return_token(x)))

# %%
df.head()
# Out:
#                                                Titre  \
# 0         Impossible de valider les points fidélités
# 1  Restaurant TRÈS TRÈS SALE,  service pitoyable ...
# 2                                               Long
# 3                                             Dépité
# 4                            Toujours des oublies!!!
#
#                                                 Avis                  Nom  \
# 0  Organisation nulle. Impossible de valider les ...             Kinaki64
# 1  Je savais que ce Mcdo était lent et qu'ils ess...           Juju_64000
# 2  Pour 3 café  plus viennoisrie 30 min de attent...             benoit l
# 3  J'habite à 10min de ce resto, pratique pour y ...  Destribois-Frederic
# 4  Encore et toujours!!!\nSi ce n'est pas une sau...  Destribois-Frederic
#
#            Date_pub     Date_visite Stars  \
# 0    5 janvier 2020    janvier 2020     1
# 1  17 décembre 2019   décembre 2019     1
# 2   1 novembre 2019   novembre 2019     1
# ...

# %% [markdown]
# ## Enlever les mots les plus fréquents

# %%
from nltk.corpus import stopwords
stopWords = set(stopwords.words('french'))

# %%
clean_words = []
for token in return_token(All_text):
    if token not in stopWords:
        clean_words.append(token)

len(clean_words)
# Out:
# 9618

# %% [markdown]
# ## Reconnaissance d’entités nommées (NER)

# %%
def return_NER(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner le texte et le label pour chaque entité
    return [(X.text, X.label_) for X in doc.ents]

# %%
return_NER(All_text)[:20]+['...']
# Out:
# [('mcdo', 'PER'),
#  ('mac do sale personnel', 'MISC'),
#  ('dégueu', 'MISC'),
#  ('mcdonald', 'ORG'),
#  ('ps', 'ORG'),
#  ('insultée":j\'', 'MISC'),
#  ('mcdo', 'PER'),
#  ('mac', 'MISC'),
#  ('!!!!!', 'MISC'),
#  ('mcdo', 'PER'),
#  ('ci', 'PER'),
#  ('mcdo', 'PER'),
#  ('mac do sale personnel', 'MISC'),
#  ('dégueu', 'MISC'),
#  ('ci', 'LOC'),
#  ('mcdo', 'PER'),
#  ('mac do sale personnel', 'MISC'),
#  ('dégueu', 'MISC'),
#  ('ci', 'LOC'),
#  ('c', 'MISC'),
#  '...']

# %%
from spacy import displacy

doc = nlp(All_text)
#displacy.render(doc, style="ent", jupyter=True)

# %% [markdown]
#  ## L’étiquetage morpho-syntaxique

# %%
def return_POS(sentence):
    # Tokeniser la phrase
    doc = nlp(sentence)
    # Retourner les étiquettes de chaque token
    return [(X, X.pos_) for X in doc]

# %%
return_POS(All_text)[:20]+['...']
# Out:
# [(organisation, 'NOUN'),
#  (nulle, 'ADJ'),
#  (., 'PUNCT'),
#  (impossible, 'ADJ'),
#  (de, 'ADP'),
#  (valider, 'VERB'),
#  (les, 'DET'),
#  (points, 'NOUN'),
#  (fidélités, 'VERB'),
#  (pour, 'ADP'),
#  (avoir, 'VERB'),
#  (la, 'DET'),
#  (réduction, 'NOUN'),
#  (,, 'PUNCT'),
#  (par, 'ADP'),
#  (contre, 'ADP'),
#  (pour, 'ADP'),
#  (payer, 'VERB'),
#  (plein, 'ADJ'),
#  (tarif, 'VERB'),
#  '...']

# %% [markdown]
# ## Opinion analyse

# %%
df["is_bad_review"] = df["Stars"].apply(lambda x: 1 if int(x) < 2 else 0)

# %% [markdown]
# ## Feature engineering(Using Vader):polarity_scores

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# add sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
df["sentiments"] =df["Avis"].apply(lambda x: sid.polarity_scores(x))
df = pd.concat([df.drop(['sentiments'], axis=1), df['sentiments'].apply(pd.Series)], axis=1)

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
df.to_csv ('tripadvasor.csv')

# %%
class OpinionAnalysis:

    

    def DownloadData(self):
        
        csvFile = open('tripadvasor.csv', 'a')

        # Use csv writer
        #csvWriter = csv.writer(csvFile)


        # creating some variables to store info
        polarity = 0
        positive = 0
        wpositive = 0
        spositive = 0
        negative = 0
        wnegative = 0
        snegative = 0
        neutral = 0


        # iterating through tweets fetched
        for tweet in df['review_clean']:
            #Append to temp so that we can store in csv later. I use encode UTF-8
            #self.tweetText.append(self.cleanTweet(tweet.text).encode('utf-8'))
            # print (tweet.text.translate(non_bmp_map))    #print tweet's text
            analysis = TextBlob(tweet)
            # print(analysis.sentiment)  # print tweet's polarity
            polarity += analysis.sentiment.polarity  # adding up polarities to find the average later

            if (analysis.sentiment.polarity == 0):  # adding reaction of how people are reacting to find average later
                neutral += 1
            elif (analysis.sentiment.polarity > 0 and analysis.sentiment.polarity <= 0.3):
                wpositive += 1
            elif (analysis.sentiment.polarity > 0.3 and analysis.sentiment.polarity <= 0.6):
                positive += 1
            elif (analysis.sentiment.polarity > 0.6 and analysis.sentiment.polarity <= 1):
                spositive += 1
            elif (analysis.sentiment.polarity > -0.3 and analysis.sentiment.polarity <= 0):
                wnegative += 1
            elif (analysis.sentiment.polarity > -0.6 and analysis.sentiment.polarity <= -0.3):
                negative += 1
            elif (analysis.sentiment.polarity > -1 and analysis.sentiment.polarity <= -0.6):
                snegative += 1


        # Write to csv and close csv file
        #csvWriter.writerow(self.tweetText)
        #csvFile.close()
        NoOfTerms=len(df)
        # finding average of how people are reacting
        positive = self.percentage(positive, NoOfTerms)
        wpositive = self.percentage(wpositive, NoOfTerms)
        spositive = self.percentage(spositive, NoOfTerms)
        negative = self.percentage(negative, NoOfTerms)
        wnegative = self.percentage(wnegative, NoOfTerms)
        snegative = self.percentage(snegative, NoOfTerms)
        neutral = self.percentage(neutral, NoOfTerms)

        # finding average reaction
        polarity = polarity / NoOfTerms

        # printing out data
        print("How people are reacting on Mc'donalds by analyzing " + str(len(df)) + " avis.")
        print()
        print("General Report: ")

        if (polarity == 0):
            print("Neutral")
        elif (polarity > 0 and polarity <= 0.3):
            print("Weakly Positive")
        elif (polarity > 0.3 and polarity <= 0.6):
            print("Positive")
        elif (polarity > 0.6 and polarity <= 1):
            print("Strongly Positive")
        elif (polarity > -0.3 and polarity <= 0):
            print("Weakly Negative")
        elif (polarity > -0.6 and polarity <= -0.3):
            print("Negative")
        elif (polarity > -1 and polarity <= -0.6):
            print("Strongly Negative")

        print()
        print("Detailed Report: ")
        print(str(positive) + "% people thought it was positive")
        print(str(wpositive) + "% people thought it was weakly positive")
        print(str(spositive) + "% people thought it was strongly positive")
        print(str(negative) + "% people thought it was negative")
        print(str(wnegative) + "% people thought it was weakly negative")
        print(str(snegative) + "% people thought it was strongly negative")
        print(str(neutral) + "% people thought it was neutral")

        self.plotPieChart(positive, wpositive, spositive, negative, wnegative, snegative, neutral,'MCdonalds France', NoOfTerms)


    def cleanTweet(self, tweet):
        # Remove Links, Special Characters etc from tweet
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) | (\w +:\ / \ / \S +)", " ", tweet).split())

    # function to calculate percentage
    def percentage(self, part, whole):
        temp = 100 * float(part) / float(whole)
        return format(temp, '.2f')

    def plotPieChart(self, positive, wpositive, spositive, negative, wnegative, snegative, neutral, searchTerm, noOfSearchTerms):
        labels = ['Positive [' + str(positive) + '%]', 'Weakly Positive [' + str(wpositive) + '%]','Strongly Positive [' + str(spositive) + '%]', 'Neutral [' + str(neutral) + '%]',
                  'Negative [' + str(negative) + '%]', 'Weakly Negative [' + str(wnegative) + '%]', 'Strongly Negative [' + str(snegative) + '%]']
        sizes = [positive, wpositive, spositive, neutral, negative, wnegative, snegative]
        colors = ['yellowgreen','lightgreen','darkgreen', 'gold', 'red','lightsalmon','darkred']
        patches, texts = plt.pie(sizes, colors=colors, startangle=90)
        plt.legend(patches, labels, loc="best")
        plt.title('How people are reacting on ' + searchTerm + ' by analyzing ' + str(noOfSearchTerms) + ' Tweets.')
        plt.axis('equal')
        plt.tight_layout()
        plt.show()

# %%
objet = OpinionAnalysis()
objet.DownloadData()
# Out:
# How people are reacting on Mc'donalds by analyzing 440 avis.
#
# General Report:
# Weakly Positive
#
# Detailed Report:
# 5.68% people thought it was positive
# 15.68% people thought it was weakly positive
# 2.95% people thought it was strongly positive
# 0.00% people thought it was negative
# 5.68% people thought it was weakly negative
# 2.05% people thought it was strongly negative
# 65.91% people thought it was neutral

# %%
# add number of characters column
df["nb_chars"] = df["Avis"].apply(lambda x: len(x))

# add number of words column
df["nb_words"] =df["Avis"].apply(lambda x: len(x.split(" ")))

# %% [markdown]
#  ## vector representations for every review(using Gensim)

# %%
# create doc2vec vector columns
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(df["review_clean"].apply(lambda x: x.split(" ")))]

# train a Doc2Vec model with our text data
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# transform each document into a vector data
doc2vec_df = df["review_clean"].apply(lambda x: model.infer_vector(x.split(" "))).apply(pd.Series)
doc2vec_df.columns = ["doc2vec_vector_" + str(x) for x in doc2vec_df.columns]
reviews_df = pd.concat([df, doc2vec_df], axis=1)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
#add tf-idfs columns
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(min_df = 10)
tfidf_result = tfidf.fit_transform(reviews_df["review_clean"]).toarray()
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = reviews_df.index
reviews_df = pd.concat([reviews_df, tfidf_df], axis=1)

# %% [markdown]
# ## Exploratory data analysis

# %%
# show is_bad_review distribution
reviews_df["is_bad_review"].value_counts(normalize = True)
# Out:
# 1    0.545455
# 0    0.454545
# Name: is_bad_review, dtype: float64

# %%
# wordcloud function

from wordcloud import WordCloud
import matplotlib.pyplot as plt

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color = 'white',
        max_words = 200,
        max_font_size = 40, 
        scale = 3,
        random_state = 42
    ).generate(str(data))

    fig = plt.figure(1, figsize = (20, 20))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize = 20)
        fig.subplots_adjust(top = 2.3)

    plt.imshow(wordcloud)
    plt.show()
    
# print wordcloud
show_wordcloud(reviews_df["review_clean"])

# %%
# plot sentiment distribution for positive and negative reviews

import seaborn as sns
subset=pd.DataFrame()
plt.figure(figsize=(16, 10))
for x in [0, 1]:
    add=[]
    subset=pd.DataFrame()
    
    if x == 0:
        label = "Good reviews"
    else:
        label = "Bad reviews"
    for i in range(len(reviews_df)):
        if(reviews_df['is_bad_review'].iloc[i]==x):
            add.append(reviews_df['compound'].iloc[i])
    subset['compound']=add
    print(subset.shape)      
            
    sns.distplot(subset['compound'], hist = False, label = label)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (200, 1)
# (240, 1)

# %% [markdown]
# ## emoticon-based-sentiment-analysis

# %%
import emoji
import regex

# %%
df_emoji=pd.DataFrame()
emoji_list = []
data=[]

Avis=[]
Titre=[]

# %%
for i in range(len(df)):
    words=[]
    sum=0
    data = regex.findall(r'\X', df['Avis'].iloc[i])
    for word in data:
    
        if any(char in emoji.UNICODE_EMOJI for char in word):
            sum+=1
            words.append(word)
    if(sum>0):
        Avis.append(df['Avis'].iloc[i])
        Titre.append(df['Titre'].iloc[i])
        emoji_list.append(words)

# %%
len(emoji_list)
# Out:
# 6

# %%
df_emoji['All_empji']=emoji_list
df_emoji['Avis']=Avis
df_emoji['Titre']=Titre
df_emoji
# Out:
#    All_empji                                               Avis  \
# 0     [🙁, 🙁]  Commande complètement fausse au drive\nBurger ...
# 1  [🙉, 🙈, 🐵]  Nous attendons plus de choix durant l'année no...
# 2        [👍]  Je suis allée au Mac do le 27 décembre à 21h d...
# 3       [👍🏼]  Que dire de plus c'est un MacDonald comme pas ...
# 4       [👍🏼]  Que dire de plus c'est un MacDonald comme pas ...
# 5        [🤔]  Finir nos vacances en prenant le temps de s’ar...
#
#                                                Titre
# 0                       Commande complètement fausse
# 1                A quand le retour du royal cheese ?
# 2  Ont comprend mieu l’obtention de la dernier pl...
# 3                           Avec mes petits enfants
# 4                           Avec mes petits enfants
# 5                        Première et dernière fois!!

# %% [markdown]
# ##  Modèle LDA-TFIDF

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim.corpora import Dictionary
from gensim.models import TfidfModel, LdaMulticore
from gensim.models import CoherenceModel

# %%
df = df.iloc[:-10]
# Les 10 dernières lignes sont réservées pour le test
from gensim.models import TfidfModel, LdaMulticore
model_tfidf = TfidfModel(bow_corpus,normalize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-fe48c982c1ab> in <module>
#       2 # Les 10 dernières lignes sont réservées pour le test
#       3 from gensim.models import TfidfModel, LdaMulticore
# ----> 4 model_tfidf = TfidfModel(bow_corpus,normalize=True)
#
# NameError: name 'bow_corpus' is not defined

# %%
# Hyperparameter Tuning

topics_range = range(2, 20, 1)
model_results = { 'Topics': [],
                 'Coherence': []
                }

for k in topics_range:
    lda_model_test = LdaMulticore(corpus=corpus_tfidf, id2word=dct, num_topics=k, random_state=42, chunksize=100, iterations=25, passes=2, workers=3)
    coherence_model_lda = CoherenceModel(model=lda_model_test, texts=processed_docs, dictionary=dct, coherence='c_v')    
    cv = coherence_model_lda.get_coherence()
    model_results['Topics'].append(k)
    model_results['Coherence'].append(cv)

plt.plot(model_results['Topics'], model_results['Coherence'])
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b66fd261ee5> in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined
